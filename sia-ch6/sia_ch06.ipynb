# %% [markdown]
# # Chapter 6

# %%
from pyspark.streaming import StreamingContext

# %%
batchDurationInSecs = 5
ssc = StreamingContext(sc, batchDuration=batchDurationInSecs)

# %% [markdown]
# #### Monitors the given dir and reads each newly created file
# [Ref: textFileStream](http://spark.apache.org/docs/latest/api/python/pyspark.streaming.html#pyspark.streaming.StreamingContext.textFileStream)

# %%
# This will create a DStream (discretized stream), representing a sequence of RDDs,
# periodically created from the input stream.
fileStream = ssc.textFileStream('/home/deepakt/Documents/dev/spark/sia/sia-ch6/dataIn')

# %%
# Parse each line of DStream
from datetime import datetime
def parseOrder(line):
    f = line.split(',')
    if f[6] == 'B' or f[6] == 'S':
        return [{
            'time': datetime.strptime(f[0], '%Y-%m-%d %H:%M:%S'),
            'orderId': long(f[1]),
            'clientId': long(f[2]),
            'symbol': f[3],
            'amout': int(f[4]),
            'price': float(f[5]),
            'buy': f[6] == 'B'
        }]
    return []

# %%
ordersStream = fileStream.flatMap(parseOrder)

# %%
ordersStream.pprint(1)

# %%
# Count number of buys and sells by creating tuple and reduce
from operator import add
numPerType = ordersStream.map(lambda order: (order['buy'], 1L)).reduceByKey(add)

# %%
numPerType.pprint(2)

# %%
# Store it to file
numPerType.repartition(1).saveAsTextFiles(prefix='dataOut/output', suffix='txt')

# %%
ssc.start()
# Out:
# -------------------------------------------
# Time: 2017-09-22 11:08:35
# -------------------------------------------
# {'orderId': 1L, 'buy': True, 'symbol': u'EPE', 'clientId': 80L, 'time': datetime.datetime(2016, 3, 22, 20, 25, 28), 'price': 51.0, 'amout': 710}
# ...
#
# -------------------------------------------
# Time: 2017-09-22 11:08:35
# -------------------------------------------
# (False, 4980L)
# (True, 5020L)
#
# -------------------------------------------
# Time: 2017-09-22 11:08:40
# -------------------------------------------
# {'orderId': 10001L, 'buy': True, 'symbol': u'ABX', 'clientId': 58L, 'time': datetime.datetime(2016, 3, 22, 20, 25, 28), 'price': 6.0, 'amout': 63}
# ...
#
# -------------------------------------------
# Time: 2017-09-22 11:08:40
# -------------------------------------------
# (False, 4926L)
# (True, 5074L)
#
# -------------------------------------------
# Time: 2017-09-22 11:08:45
# -------------------------------------------
# {'orderId': 30001L, 'buy': False, 'symbol': u'UAL', 'clientId': 5L, 'time': datetime.datetime(2016, 3, 22, 20, 25, 28), 'price': 78.0, 'amout': 953}
# ...
#
# -------------------------------------------
# Time: 2017-09-22 11:08:45
# -------------------------------------------
# (False, 9929L)
# (True, 10071L)
#
# -------------------------------------------
# Time: 2017-09-22 11:08:50
# -------------------------------------------
# {'orderId': 40001L, 'buy': False, 'symbol': u'CHK', 'clientId': 2L, 'time': datetime.datetime(2016, 3, 22, 20, 25, 28), 'price': 40.0, 'amout': 739}
# ...
#
# -------------------------------------------
# Time: 2017-09-22 11:08:50
# -------------------------------------------
# (False, 9917L)
# (True, 10083L)
#
# -------------------------------------------
# Time: 2017-09-22 11:08:55
# -------------------------------------------
# {'orderId': 60001L, 'buy': False, 'symbol': u'PYPL', 'clientId': 27L, 'time': datetime.datetime(2016, 3, 22, 20, 25, 29), 'price': 91.0, 'amout': 992}
# ...
#
# -------------------------------------------
# Time: 2017-09-22 11:08:55
# -------------------------------------------
# (False, 5035L)
# (True, 4965L)
#
# -------------------------------------------
# Time: 2017-09-22 11:09:00
# -------------------------------------------
# {'orderId': 70001L, 'buy': True, 'symbol': u'WNC', 'clientId': 76L, 'time': datetime.datetime(2016, 3, 22, 20, 25, 29), 'price': 6.0, 'amout': 565}
# ...
#
# -------------------------------------------
# Time: 2017-09-22 11:09:00
# -------------------------------------------
# (False, 9931L)
# (True, 10069L)
#
# -------------------------------------------
# Time: 2017-09-22 11:09:05
# -------------------------------------------
# {'orderId': 90001L, 'buy': False, 'symbol': u'NFLX', 'clientId': 71L, 'time': datetime.datetime(2016, 3, 22, 20, 25, 29), 'price': 5.0, 'amout': 805}
# ...
#
# -------------------------------------------
# Time: 2017-09-22 11:09:05
# -------------------------------------------
# (False, 9975L)
# (True, 10025L)
#
# -------------------------------------------
# Time: 2017-09-22 11:09:10
# -------------------------------------------
# {'orderId': 110001L, 'buy': False, 'symbol': u'KGC', 'clientId': 68L, 'time': datetime.datetime(2016, 3, 22, 20, 25, 29), 'price': 61.0, 'amout': 361}
# ...
#
# -------------------------------------------
# Time: 2017-09-22 11:09:10
# -------------------------------------------
# (False, 4876L)
# (True, 5124L)
#
# -------------------------------------------
# Time: 2017-09-22 11:09:15
# -------------------------------------------
# {'orderId': 120001L, 'buy': True, 'symbol': u'BUD', 'clientId': 14L, 'time': datetime.datetime(2016, 3, 22, 20, 25, 29), 'price': 54.0, 'amout': 715}
# ...
#
# -------------------------------------------
# Time: 2017-09-22 11:09:15
# -------------------------------------------
# (False, 9948L)
# (True, 10052L)
#
# -------------------------------------------
# Time: 2017-09-22 11:09:20
# -------------------------------------------
# {'orderId': 150001L, 'buy': False, 'symbol': u'ITUB', 'clientId': 2L, 'time': datetime.datetime(2016, 3, 22, 20, 25, 30), 'price': 38.0, 'amout': 491}
# ...
#
# -------------------------------------------
# Time: 2017-09-22 11:09:20
# -------------------------------------------
# (False, 9975L)
# (True, 10025L)
#
# -------------------------------------------
# Time: 2017-09-22 11:09:25
# -------------------------------------------
# {'orderId': 160001L, 'buy': False, 'symbol': u'LEU', 'clientId': 61L, 'time': datetime.datetime(2016, 3, 22, 20, 25, 30), 'price': 62.0, 'amout': 371}
# ...
#
# -------------------------------------------
# Time: 2017-09-22 11:09:25
# -------------------------------------------
# (False, 4970L)
# (True, 5030L)
#
# -------------------------------------------
# Time: 2017-09-22 11:09:30
# -------------------------------------------
# {'orderId': 170001L, 'buy': False, 'symbol': u'BUD', 'clientId': 101L, 'time': datetime.datetime(2016, 3, 22, 20, 25, 30), 'price': 36.0, 'amout': 215}
# ...
#
# -------------------------------------------
# Time: 2017-09-22 11:09:30
# -------------------------------------------
# (False, 10067L)
# (True, 9933L)
#
# -------------------------------------------
# Time: 2017-09-22 11:09:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:09:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:09:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:09:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:09:45
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:09:45
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:09:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:09:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:09:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:09:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:15
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:15
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:25
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:25
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:45
# -------------------------------------------
# -------------------------------------------
# Time: 2017-09-22 11:10:45
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:10:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:11:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:11:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:11:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:11:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:11:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2017-09-22 11:11:10
# -------------------------------------------

# %%
ssc.stop(False)

# %%
# Read the result
allCounts = sc.textFile("dataOut/output-*.txt/")

# %%
# Each line is a string; needs to converted to tuple
allCounts.take(10)
# Out:
# [u'(False, 5035L)',
#  u'(True, 4965L)',
#  u'(False, 4926L)',
#  u'(True, 5074L)',
#  u'(False, 10067L)',
#  u'(True, 9933L)',
#  u'(False, 4876L)',
#  u'(True, 5124L)',
#  u'(False, 9975L)',
#  u'(True, 10025L)']

# %%
import ast
rdd_buysell = allCounts.map(lambda s: ast.literal_eval(s))

# %%
rdd_buysell.take(10)
# Out:
# [(False, 5035L),
#  (True, 4965L),
#  (False, 4926L),
#  (True, 5074L),
#  (False, 10067L),
#  (True, 9933L),
#  (False, 4876L),
#  (True, 5124L),
#  (False, 9975L),
#  (True, 10025L)]

# %%
from operator import add
rdd_buysell.reduceByKey(add).collect()
# Out:
# [(False, 94529L), (True, 95471L)]
